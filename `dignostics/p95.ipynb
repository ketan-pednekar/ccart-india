# %%
import rasterio
import numpy as np

path = r"C:\CMIP_data\cmip6\Climada\Projects\ccart-india\ccart\flood\outputs\p95\p95_chirps_2day.tif"

with rasterio.open(path) as src:
    arr = src.read(1)
    print("Shape:", arr.shape)
    print("Min:", np.nanmin(arr))
    print("Max:", np.nanmax(arr))
    print("Nodata:", src.nodata)
    print("CRS:", src.crs)
    print("Transform:", src.transform)
# Out:
# Shape: (607, 586)
# Min: 0.0
# Max: 146.7002
# Nodata: None
# CRS: EPSG:4326
# Transform: | 0.05, 0.00, 68.15|
# | 0.00,-0.05, 37.10|
# | 0.00, 0.00, 1.00|
